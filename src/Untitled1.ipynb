# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/oksygen/merged.csv')
df.set_index('Timestamp', inplace=True)

# %%
df.tail()
# Out:
#              Pos1m3Temp  Pos1m3DO  Pos1m6Temp  Pos1m6DO  Pos1m9Temp  Pos1m9DO  \
# Timestamp
# 07-05 10:14         NaN       NaN         NaN       NaN         NaN       NaN
# 07-05 10:15         NaN       NaN         NaN       NaN         NaN       NaN
# 07-05 10:16         NaN       NaN         NaN       NaN         NaN       NaN
# 07-05 10:17         NaN       NaN         NaN       NaN         NaN       NaN
# 07-05 10:18         NaN       NaN         NaN       NaN         NaN       NaN
#
#              Pos1m12Temp  Pos1m12DO  Pos4m3Temp  Pos4m3DO  ...  Pos32m4DO  \
# Timestamp                                                  ...
# 07-05 10:14          NaN        NaN         NaN       NaN  ...        NaN
# 07-05 10:15          NaN        NaN         NaN       NaN  ...        NaN
# 07-05 10:16          NaN        NaN         NaN       NaN  ...        NaN
# 07-05 10:17          NaN        NaN         NaN       NaN  ...        NaN
# 07-05 10:18          NaN        NaN         NaN       NaN  ...        NaN
#
#              DO31Temp     DO31DO  NorthDO  NorthTemp  SouthOutsideDO  \
# Timestamp
# 07-05 10:14    17.595  94.541659      NaN        NaN             NaN
# 07-05 10:15    17.468  94.293639      NaN        NaN             NaN
# 07-05 10:16    17.367  94.523961      NaN        NaN             NaN
# 07-05 10:17    17.232  94.228182      NaN        NaN             NaN
# 07-05 10:18    17.156  95.034357      NaN        NaN             NaN
#
#              SouthOutsideTemp  SouthDO  SouthTemp  TideLevel
# Timestamp
# 07-05 10:14               NaN      NaN        NaN        NaN
# 07-05 10:15               NaN      NaN        NaN        NaN
# 07-05 10:16               NaN      NaN        NaN        NaN
# 07-05 10:17               NaN      NaN        NaN        NaN
# 07-05 10:18               NaN      NaN        NaN        NaN
#
# [5 rows x 51 columns]

# %%
fig, ax = plt.subplots()
#ax.plot(data['Pos1m3Temp'], 'b-', label='Pos1m3Temp')
#ax.set_xticklabels(rotation = (45), fontsize = 10, va='bottom', ha='left')
#ax.set_xticks(np.arange(len))
df['NorthTemp'].plot(figsize=[10,8], rot=45)
df.describe()
# Out:
#         Pos1m3Temp     Pos1m3DO   Pos1m6Temp     Pos1m6DO   Pos1m9Temp  \
# count  3088.000000  3088.000000  3088.000000  3088.000000  3088.000000
# mean     10.279756    74.918275    10.133253    75.101304     9.937559
# std       0.225366     9.982629     0.236703     9.256361     0.290502
# min       9.820000    56.431539     9.417000    55.997550     9.138000
# 25%      10.104000    67.035602     9.959000    67.512388     9.765000
# 50%      10.295000    72.532341    10.133000    74.955920     9.957000
# 75%      10.450000    83.506089    10.288000    82.269821    10.112000
# max      10.749000    97.926551    10.804000    95.305548    10.829000
#
#           Pos1m9DO  Pos1m12Temp    Pos1m12DO  Pos4m3Temp   Pos4m3DO  ...  \
# count  3088.000000  3088.000000  3088.000000   27.000000  27.000000  ...
# mean     81.487193     9.862700    83.395177   10.283370  84.184775  ...
# std       6.786177     0.318451     6.638727    0.226784   2.381746  ...
# min      59.306835     9.038000    63.169247   10.141000  81.348365  ...
# 25%      77.286471     9.629000    79.189746   10.169000  82.380296  ...
# 50%      81.589133     9.862500    83.289507   10.196000  83.652418  ...
# 75%      86.137332    10.059000    87.958767   10.269000  85.396981  ...
# max      97.462750    10.912000    98.141385   10.993000  92.373482  ...
#
#         Pos32m4DO     DO31Temp       DO31DO      NorthDO    NorthTemp  \
# count  127.000000  4002.000000  4002.000000  3994.000000  3994.000000
# mean    98.434566    10.419339    93.582150    69.323026    10.253174
# std      1.916425     0.594253     5.780275     9.583342     0.225558
# min     91.628593     9.819000    68.987365    52.052530     9.721779
# 25%     97.980696    10.130000    89.604764    61.302175    10.088442
# 50%     99.289577    10.421000    94.848535    66.959990    10.244410
# 75%     99.725145    10.603000    98.382786    77.365110    10.418765
# max    100.410892    17.713000   101.904438    92.506730    10.868950
#
#        SouthOutsideDO  SouthOutsideTemp      SouthDO    SouthTemp   TideLevel
# count     3994.000000       3994.000000  3994.000000  3994.000000  401.000000
# mean        94.722372         10.366766    73.708200    10.269055  159.573815
# std          7.233596          0.250217    11.249443     0.233199   92.936679
# min         72.058520          9.871695    51.958890     9.727741   27.600000
# 25%         88.923630         10.149235    64.904713    10.094335   68.700000
# 50%         96.554575         10.371145    71.670155    10.280360  150.300000
# 75%        100.460950         10.577260    82.439048    10.436490  248.600000
# max        107.864800         10.972700    98.328790    10.829580  316.100000
#
# [8 rows x 51 columns]
